# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display
pd.set_option("display.max_columns", 500)

# %%
df = pd.read_csv("data/churn.txt")
df.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    PA             163        806  403-2562         no        yes
# 1    SC              15        836  158-8416        yes         no
# 2    MO             131        777  896-6253         no        yes
# 3    WY              75        878  817-5729        yes        yes
# 4    WY             146        878  450-4942        yes         no
#
#    VMail Message   Day Mins  Day Calls  Day Charge  Eve Mins  Eve Calls  \
# 0            300   8.162204          3    7.579174  3.933035          4
# 1              0  10.018993          4    4.226289  2.325005          0
# 2            300   4.708490          3    4.768160  4.537466          3
# 3            700   1.268734          3    2.567642  2.528748          5
# 4              0   2.696177          3    5.908916  6.015337          3
#
#    Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  \
# ...

# %% [markdown]
# ## Check for missing values

# %%
df.isnull().sum()
# Out:
# State             0
# Account Length    0
# Area Code         0
# Phone             0
# Int'l Plan        0
# VMail Plan        0
# VMail Message     0
# Day Mins          0
# Day Calls         0
# Day Charge        0
# Eve Mins          0
# Eve Calls         0
# Eve Charge        0
# Night Mins        0
# Night Calls       0
# Night Charge      0
# Intl Mins         0
# Intl Calls        0
# Intl Charge       0
# CustServ Calls    0
# Churn?            0
# dtype: int64

# %% [markdown]
# There is no missing value in the dataset. Nice!

# %% [markdown]
# ## Check the distribution of the label

# %%
df["Churn?"].value_counts()
# Out:
# False.    2502
# True.     2498
# Name: Churn?, dtype: int64

# %% [markdown]
# This is a balanced dataset.

# %% [markdown]
# ## Check the data distribution of each feature

# %%
# Frequency tables for each categorical feature
for column in df.select_dtypes(include=["object"]).columns:
    display(pd.crosstab(index=df[column], columns="% observations", normalize="columns"))

# Histograms for each numeric features
display(df.describe())
# %matplotlib inline
hist = df.hist(bins=30, sharey=True, figsize=(10, 10))
# Out:
# col_0  % observations
# State
# AK             0.0170
# AL             0.0200
# AR             0.0220
# AZ             0.0180
# CA             0.0208
# CO             0.0182
# CT             0.0178
# DC             0.0224
# DE             0.0182
# FL             0.0178
# GA             0.0166
# HI             0.0190
# IA             0.0206
# ID             0.0222
# IL             0.0198
# IN             0.0190
# KS             0.0158
# KY             0.0182
# LA             0.0202
# MA             0.0208
# MD             0.0226
# ME             0.0148
# MI             0.0202
# MN             0.0220
# MO             0.0212
# MS             0.0212
# MT             0.0180
# NC             0.0190
# ND             0.0160
# NE             0.0218
# NH             0.0188
# NJ             0.0202
# NM             0.0166
# NV             0.0198
# NY             0.0196
# OH             0.0222
# OK             0.0186
# OR             0.0204
# PA             0.0198
# RI             0.0240
# ...

# %%
df.Phone.value_counts()
# Out:
# 614-5668    2
# 305-6075    1
# 854-8433    1
# 390-8596    1
# 268-4279    1
#            ..
# 158-9040    1
# 190-8887    1
# 546-3939    1
# 656-6911    1
# 294-2849    1
# Name: Phone, Length: 4999, dtype: int64

# %% [markdown]
# We will use "phone number" column as customer ID as it is nearly unique for each customer

# %%
df=df.drop_duplicates(subset="Phone")

# %% [markdown]
# ## Check the correlation between features

# %%
for column in df.select_dtypes(include=["object"]).columns:
    if column != "Churn?":
        display(pd.crosstab(index=df[column], columns=df["Churn?"], normalize="columns"))

for column in df.select_dtypes(exclude=["object"]).columns:
    print(column)
    hist = df[[column, "Churn?"]].hist(by="Churn?", bins=30)
    plt.show()
# Out:
# Churn?    False.     True.
# State
# AK      0.015588  0.018415
# AL      0.021583  0.018415
# AR      0.022782  0.021217
# AZ      0.015588  0.020416
# CA      0.020384  0.021217
# CO      0.018785  0.017614
# CT      0.015588  0.020016
# DC      0.022382  0.022418
# DE      0.018385  0.018014
# FL      0.019984  0.015612
# GA      0.017986  0.015212
# HI      0.019185  0.018815
# IA      0.018385  0.022818
# ID      0.021583  0.022818
# IL      0.021982  0.017614
# IN      0.021583  0.016413
# KS      0.014788  0.016813
# KY      0.017186  0.019215
# LA      0.020783  0.019616
# MA      0.021183  0.020416
# MD      0.019584  0.025620
# ME      0.013589  0.016013
# MI      0.018785  0.021617
# MN      0.022782  0.021217
# MO      0.020783  0.021617
# MS      0.019584  0.022818
# MT      0.017586  0.018415
# NC      0.017186  0.020817
# ND      0.017186  0.014812
# NE      0.019185  0.024420
# NH      0.019984  0.017614
# NJ      0.022382  0.018014
# NM      0.017186  0.016013
# ...

# %%
display(df.corr())
pd.plotting.scatter_matrix(df, figsize=(12, 12))
plt.show()
# Out:
# /tmp/ipykernel_21776/2098539270.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   display(df.corr())
#                 Account Length  Area Code  VMail Message  Day Mins  Day Calls  \
# Account Length        1.000000  -0.037483      -0.009030 -0.015878   0.011659
# Area Code            -0.037483   1.000000      -0.017609 -0.013293   0.013661
# VMail Message        -0.009030  -0.017609       1.000000 -0.143272   0.002762
# Day Mins             -0.015878  -0.013293      -0.143272  1.000000  -0.087598
# Day Calls             0.011659   0.013661       0.002762 -0.087598   1.000000
# Day Charge           -0.007468  -0.007918      -0.182712  0.667941  -0.222556
# Eve Mins              0.000213  -0.012286      -0.104667  0.482641   0.033903
# ...

# %%
# get the value bigger than 0.9
df_cor=df.corr().abs().unstack().sort_values(ascending=False)
df_cor[df_cor>0.9]
# Out:
# /tmp/ipykernel_21776/3963147464.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_cor=df.corr().abs().unstack().sort_values(ascending=False)
# Account Length  Account Length    1.0
# Area Code       Area Code         1.0
# Intl Charge     Intl Charge       1.0
# Intl Calls      Intl Calls        1.0
# Intl Mins       Intl Mins         1.0
# Night Charge    Night Charge      1.0
# Night Calls     Night Calls       1.0
# Night Mins      Night Mins        1.0
# Eve Charge      Eve Charge        1.0
# Eve Calls       Eve Calls         1.0
# Eve Mins        Eve Mins          1.0
# Day Charge      Day Charge        1.0
# Day Calls       Day Calls         1.0
# Day Mins        Day Mins          1.0
# VMail Message   VMail Message     1.0
# CustServ Calls  CustServ Calls    1.0
# dtype: float64

# %% [markdown]
# Current feaures are not highly correlated with each other, so we don't need to drop any feature.
